# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib"

import os
import sys

os.environ["PYTHONPATH"]="/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib"
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/ultralytics')
# Out:
# /content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/Hazy.yaml", epochs=150, pretrained=True, iou=0.9, visualize=True, patience=0)  # train the model
results = model.val()  # evaluate model performance on the validation set
#results = model("/content/drive/MyDrive/Colab Notebooks/Bruce/Dataset-fish/2023-Jan-jpg-480/images/test/test-fishNoFish")  # predict on an image
#success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.17 🚀 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# to generate inference results on testing dataset
# !chmod 755 bin/yolo
PATH="runs/detect/train59/"
# !bin/yolo task=detect mode=predict model='{PATH}/weights/best.pt' save_txt=True conf=0.25 save_conf=True source='/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/images/test/images'
# Out:
# 2023-04-29 22:12:33.479145: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-29 22:12:34.590440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.17 🚀 Python-3.9.16 torch-2.0.0+cu117 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# image 1/60 /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/images/test/images/500.jpg: 288x640 6 vehicles, 67.0ms
# image 2/60 /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/images/test/images/501.jpg: 288x640 3 vehicles, 7.8ms
# ...

# %%
# each time when run time restart, chmod the local tensorboard folder
# %load_ext tensorboard
# !chmod 755 "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/tensorboard_data_server/bin/server"
# !ls -al "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/tensorboard_data_server/bin/server"
# Out:
# chmod: cannot access '/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/tensorboard_data_server/bin/server': No such file or directory
# ls: cannot access '/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/tensorboard_data_server/bin/server': No such file or directory

# %%
# run local tensorboard
# !ls "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/runs/detect/train8"
# %cd "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/"
# %tensorboard --logdir "runs/detect/train24"

# %%
# run cloud tensorboard
# !tensorboard dev upload --logdir runs/detect/train27 --name "150 epochs exr scratch unfreeze normalize=true pretrain=false fishnofish #normalize=true"

# %%
# to run resize_jpg.py
'''
# !pip install rawpy
# !pip install imageio
# !python "/content/drive/MyDrive/Colab Notebooks/Bruce/Dataset-fish/resize_jpg.py"
'''

# %%
#helper function - check if internet is alive
import urllib.request

def check_internet():
    try:
        urllib.request.urlopen('http://www.google.com', timeout=1)
        return True
    except urllib.request.URLError as err: 
        return False

if check_internet():
    print("Connected to the internet")
else:
    print("Not connected to the internet")
# Out:
# Connected to the internet

# %%
#helper function - rename ..exr
# rename ..exr to ..exr

#%cd "/content/drive/MyDrive/Colab Notebooks/Bruce/Dataset-fish/2023-Jan-log-480/images"
#!rename 's/\.\.exr$/.exr/' *..exr
#!ls -al

# %%
# uninstall pandas everytime when a new yolo version is installed
# force the system to use pandas installed at /usr/local/lib/python3.9/dist-packages/pandas/_libs
#!pip uninstall pandas
# Out:
# Found existing installation: pandas 1.5.3
# Uninstalling pandas-1.5.3:
#   Would remove:
#     /content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/pandas-1.5.3.dist-info/*
#     /content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/pandas/*
# Proceed (Y/n)? Y
#   Successfully uninstalled pandas-1.5.3

# %%
# !ls /usr/local/lib/python3.9/dist-packages/pandas/_libs
# Out:
# algos_common_helper.pxi.in
# algos.cpython-39-x86_64-linux-gnu.so
# algos.pxd
# algos.pyi
# algos.pyx
# algos_take_helper.pxi.in
# arrays.cpython-39-x86_64-linux-gnu.so
# arrays.pxd
# arrays.pyi
# arrays.pyx
# dtypes.pxd
# groupby.cpython-39-x86_64-linux-gnu.so
# groupby.pyi
# groupby.pyx
# hashing.cpython-39-x86_64-linux-gnu.so
# hashing.pyi
# hashing.pyx
# hashtable_class_helper.pxi.in
# hashtable.cpython-39-x86_64-linux-gnu.so
# hashtable_func_helper.pxi.in
# hashtable.pxd
# hashtable.pyi
# hashtable.pyx
# index_class_helper.pxi.in
# index.cpython-39-x86_64-linux-gnu.so
# indexing.cpython-39-x86_64-linux-gnu.so
# indexing.pyx
# index.pyi
# index.pyx
# __init__.py
# internals.cpython-39-x86_64-linux-gnu.so
# internals.pyi
# internals.pyx
# interval.cpython-39-x86_64-linux-gnu.so
# interval.pyx
# intervaltree.pxi.in
# join.cpython-39-x86_64-linux-gnu.so
# join.pyi
# join.pyx
# json.cpython-39-x86_64-linux-gnu.so
# khash_for_primitive_helper.pxi.in
# khash.pxd
# ...

# %%
# !pip list -v
'''
Package                       Version              Location                                               Installer
----------------------------- -------------------- ------------------------------------------------------ ---------
absl-py                       1.4.0                /usr/local/lib/python3.9/dist-packages                 pip
alabaster                     0.7.13               /usr/local/lib/python3.9/dist-packages                 pip
albumentations                1.2.1                /usr/local/lib/python3.9/dist-packages                 pip
'''

# %%
'''
# helper function to uninstall yolo8 and yolo8 requirement packages
# !pip uninstall ultralytics

# helper function to uninstall yolo8 requirements  
import re 
import subprocess

# !pip install ultralytics > temp.txt

with open('temp.txt', 'r') as file:
    for line in file:
        words = line.split()
        if len(words) >= 3:
            pac = re.sub(r'[^a-zA-Z]', "", words[3])
            print(pac)
            subprocess.call(['pip', 'uninstall', pac])
'''
# Out:
# httpspypiorgsimple
# ultralytics
# matplotlib
# thop
# PyYAML
# psutil
# pandas
# tqdm
# scipy
# numpy
# Pillow
# seaborn
# torchvision
# sentrysdk
# opencvpython
# torch
# requests
# contourpy
# importlibresources
# kiwisolver
# cycler
# packaging
# pythondateutil
# fonttools
# pyparsing
# pytz
# certifi
# idna
# charsetnormalizer
# urllib
# typingextensions
# zipp
# six

# %%
# convert Pascal VOC format into Yolo
from numpy.lib.type_check import imag
import re
import os
import cv2

img_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/original dataset/train/haze_images"
label_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/original dataset/train/haze_images_labels"
dest_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/labels/train"

for filename_jpg in os.listdir(img_path):
  yolo = ""
  img = cv2.imread(os.path.join(img_path, filename_jpg))
  img_H = img.shape[0]
  img_W = img.shape[1]
  filename_txt = os.path.join(label_path, filename_jpg.replace("jpg", "txt"))
  if filename_txt.endswith(".txt"):
    with open(os.path.join(label_path, filename_txt), 'r') as f:
      lines = f.readlines()
      for line in lines:
        x_min, y_min, x_max, y_max = [int(bbox) for bbox in line.split()[1:]]
        x_center = round((x_max + x_min) / 2  / img_W, 4)
        y_center = round((y_max + y_min) / 2 / img_H, 4)
        width = round((x_max - x_min) / img_W, 4)
        height = round((y_max - y_min) / img_H, 4)
        yolo += (f"0 {x_center} {y_center} {width} {height}\n")
    print(yolo)
    print(os.path.join(dest_path, filename_jpg.replace("jpg", "txt")))
    with open(os.path.join(dest_path, filename_jpg.replace("jpg", "txt")), 'w') as f:
      f.write(yolo)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-092f0630d443> in <cell line: 11>()
#       9 dest_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/labels/train"
#      10
# ---> 11 for filename_jpg in os.listdir(img_path):
#      12   yolo = ""
#      13   img = cv2.imread(os.path.join(img_path, filename_jpg))
#
# KeyboardInterrupt:

# %%
# convert YOLO format into Pascal VOC
from numpy.lib.type_check import imag
import re
import os
import cv2

img_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/images/test/images"
label_path = "/content/drive/MyDrive/Colab Notebooks/Bruce/Yolo8-lib/runs/detect/predict8/labels"
dest_path = "/content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results"

for filename_jpg in os.listdir(img_path):
  pascal_voc = ""
  img = cv2.imread(os.path.join(img_path, filename_jpg))
  img_H = img.shape[0]
  img_W = img.shape[1]
  filename_txt = os.path.join(label_path, filename_jpg.replace("jpg", "txt"))
  try:
    if filename_txt.endswith(".txt"):
      with open(os.path.join(label_path, filename_txt), 'r') as f:
        lines = f.readlines()
        for line in lines:
          x_center, y_center, width, height, confid = [float(bbox) for bbox in line.split()[1:]]
          x_min = (x_center - width/2) * img_W
          y_min = (y_center - height/2) * img_H
          x_max = (x_center + width/2) * img_W
          y_max = (y_center + height/2) * img_H
          pascal_voc += (f"vehicle {x_min:.2f} {y_min:.2f} {x_max:.2f} {y_max:.2f} {confid:.2f}\n")
          print(pascal_voc)
          print(os.path.join(dest_path, filename_jpg.replace("jpg", "txt")))
      with open(os.path.join(dest_path, filename_jpg.replace("jpg", "txt")), 'w') as f:
        f.write(pascal_voc)
  except:
    pass
# Out:
# vehicle 1268.00 670.00 1339.00 750.00 0.76
#
# /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results/512.txt
# vehicle 730.00 388.00 776.00 425.00 0.41
#
# /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results/513.txt
# vehicle 730.00 388.00 776.00 425.00 0.41
# vehicle 1040.00 287.00 1099.00 333.00 0.45
#
# /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results/513.txt
# vehicle 730.00 388.00 776.00 425.00 0.41
# vehicle 1040.00 287.00 1099.00 333.00 0.45
# vehicle 1047.00 367.00 1103.00 399.00 0.60
#
# /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results/513.txt
# vehicle 730.00 388.00 776.00 425.00 0.41
# vehicle 1040.00 287.00 1099.00 333.00 0.45
# vehicle 1047.00 367.00 1103.00 399.00 0.60
# vehicle 667.00 674.00 728.00 750.00 0.81
#
# /content/drive/MyDrive/Colab Notebooks/CVPR23 Object in Hazy Condition/results/513.txt
# vehicle 730.00 388.00 776.00 425.00 0.41
# ...
